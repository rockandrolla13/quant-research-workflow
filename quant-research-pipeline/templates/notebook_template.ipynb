# %% [markdown]
# # Strategy: [Name]
#
# **Source:** [Paper / PDF reference]
#
# **Spec:** [Link to strategy spec]

# %%
# Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## 1. Data Loading

# %% [markdown]
# ## 2. Signal Construction

# %% [markdown]
# ## 3. Backtest

# %% [markdown]
# ## 4. Results & Analysis
