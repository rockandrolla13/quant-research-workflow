# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..').resolve() / 'src'))

import pandas as pd
from momentum_strategy_v1.portfolio import allocate_weights

# %%
signals = pd.DataFrame({
    'AAPL': [1, 0, -1, 1],
    'MSFT': [0, 1, 0, -1],
})
risk_params = {'normalize': True, 'max_weight': 0.6, 'min_weight': -0.6}
weights = allocate_weights(signals, risk_params)
weights
