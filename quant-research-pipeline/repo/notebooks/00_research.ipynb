# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path('..').resolve() / 'src'))

import pandas as pd
from momentum_strategy_v1.spec_models import load_config
from momentum_strategy_v1.signals import calculate_rsi

# %%
config = load_config('../config.yaml')
config

# %%
prices = pd.Series([10, 11, 12, 11, 10, 9, 10, 11, 12, 13, 14, 13, 12, 11, 10], dtype=float)
rsi = calculate_rsi(prices, config.signal.rsi_period)
rsi
